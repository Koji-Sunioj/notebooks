# %%
import pandas as pd
import numpy as np
import datetime

# %%
raw = pd.read_csv("mock-data.csv").drop(columns=["base uri"])

# %%
raw["photo_id"] = raw.photo.str[0:11]

# %%
getting_there = raw.drop(columns=["photo"])

# %%
getting_there["date"] = np.nan

# %%
getting_there.loc[getting_there['collection'] == "holy sepulchre","date"] = pd.to_datetime("1940-01-3").strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
getting_there.loc[getting_there['collection'] == "damascus gate","date"] = pd.to_datetime("1940-05-12").strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
getting_there.loc[getting_there['collection'] == "western wall","date"] = pd.to_datetime("1940-10-26").strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
getting_there
# Out:
#                          title      collection  \
# 0                  procession   holy sepulchre
# 1             lighting candles  holy sepulchre
# 2                  easter mass  holy sepulchre
# 3                 sabt al noor  holy sepulchre
# 4       eastern orthodox vigil  holy sepulchre
# 5                 bishop visit  holy sepulchre
# 6           street vendor sale   damascus gate
# 7                 nuns walking   damascus gate
# 8                 man with son   damascus gate
# 9              old taxi driver   damascus gate
# 10            british tourists   damascus gate
# 11        ottoman architecture   damascus gate
# 12                 eid el adha   damascus gate
# 13              people begging   damascus gate
# 14     men praying at the wall    western wall
# 15                     sabbath    western wall
# 16  view with dome of the rock    western wall
# 17           torah celebration    western wall
# 18                    passover    western wall
# ...
